# %% [markdown]
# # Diwali Sales Analytics

# %% [markdown]
# ### Importing Lib and Dataset that we have to work upon

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\Python Project\Python_Diwali_Sales_Analysis-main\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = 'unicode_escape')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.shape #finding basic information
# Out:
# (11251, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Data Cleaning

# %%
df = df.drop_duplicates()
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df = df.drop(columns = ['Status','unnamed1'])
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df = df.fillna('')
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
for x in df.index:
    if df.loc[x,"Amount"] == '' :
        df.drop(x,inplace = True)
#removing columns that don't have any amount in them

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.head(10)
# Out:
#     User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0   1002903  Sanskriti  P00125942      F     26-35   28               0
# 1   1000732     Kartik  P00110942      F     26-35   35               1
# 2   1001990      Bindu  P00118542      F     26-35   35               1
# 3   1001425     Sudevi  P00237842      M      0-17   16               0
# 4   1000588       Joni  P00057942      M     26-35   28               1
# 5   1000588       Joni  P00057942      M     26-35   28               1
# 6   1001132       Balk  P00018042      F     18-25   25               1
# 8   1003224     Kushal  P00205642      M     26-35   35               0
# 9   1003650      Ginny  P00031142      F     26-35   26               1
# 10  1003829   Harshita  P00200842      M     26-35   34               0
#
#                State      Zone       Occupation Product_Category  Orders  \
# 0        Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.shape
# Out:
# (11231, 13)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename column if and when required
df.rename(columns = {'User_ID':'ID'}) #make it a dictionary and then replace the column names if required
# Out:
#             ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders
# count  1.123100e+04  11231.000000    11231.000000  11231.000000
# mean   1.003004e+06     35.411985        0.419998      2.489093
# std    1.716055e+03     12.756116        0.493580      1.114880
# min    1.000001e+06     12.000000        0.000000      1.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000
# 75%    1.004428e+06     43.000000        1.000000      3.000000
# max    1.006040e+06     92.000000        1.000000      4.000000

# %%
df['Age'].describe()  #to see for a specific one make a list
# Out:
# count    11231.000000
# mean        35.411985
# std         12.756116
# min         12.000000
# 25%         27.000000
# 50%         33.000000
# 75%         43.000000
# max         92.000000
# Name: Age, dtype: float64

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df['Amount'].dtypes #changing data type
# Out:
# dtype('O')

# %%
df['Amount']=df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %% [markdown]
# ### EDA

# %%
df.groupby('Age Group').mean(numeric_only = True).sort_values(by ='Amount',ascending = True)
# Out:
#                 User_ID        Age  Marital_Status    Orders       Amount
# Age Group
# 0-17       1.002652e+06  14.533784        0.378378  2.331081  9120.449324
# 18-25      1.002824e+06  21.490948        0.426518  2.473908  9177.598509
# 46-50      1.003043e+06  48.030519        0.413021  2.412004  9367.084435
# 26-35      1.003106e+06  30.447310        0.425044  2.508377  9387.514771
# 55+        1.002986e+06  73.819672        0.395785  2.519906  9557.346604
# 36-45      1.002974e+06  40.434268        0.422875  2.490359  9699.883874
# 51-55      1.003025e+06  52.997587        0.405308  2.546441  9937.164053

# %%
df2 = df.groupby('Age Group')[['Amount']].sum(numeric_only = True).sort_values(by ='Age Group',ascending = True)

# %%
df2 #1
# Out:
#              Amount
# Age Group
# 0-17        2699653
# 18-25      17235530
# 26-35      42581767
# 36-45      22135135
# 46-50       9207844
# 51-55       8237909
# 55+         4080987

# %%
df2.plot(kind = 'bar')  #seeing which age group spends what; on an average
# Out:
# <Axes: xlabel='Age Group'>

# %%
sns.countplot(x='Age Group', data=df, hue='Gender')

# Add labels and title
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Number of Males and Females in each Age Group')

# Show plot
#plt.show() #6
# Out:
# Text(0.5, 1.0, 'Number of Males and Females in each Age Group')

# %%
df7 =df.groupby('State')[['Orders']].sum(numeric_only = True).sort_values(by ='Orders',ascending = False)
df7.plot(kind = 'bar')
# Out:
# <Axes: xlabel='State'>

# %%
df3 = df.groupby('State')[['Amount']].sum(numeric_only = True).sort_values(by ='Amount',ascending = False)

# %%
df3 #2
# Out:
#                     Amount
# State
# Uttar Pradesh     19346055
# Maharashtra       14404467
# Karnataka         13523540
# Delhi             11603818
# Madhya Pradesh     8101142
# Andhra Pradesh     8037146
# Himachal Pradesh   4963368
# Haryana            4217871
# Bihar              4014669
# Gujarat            3938159
# Kerala             3894491
# Jharkhand          3026456
# Uttarakhand        2520944
# Rajasthan          1909409
# Punjab             1525800
# Telangana          1151490

# %%
colors = ['orange'] #put different colour names here

# %%
df3.plot(kind = 'bar', color = colors)
# Out:
# <Axes: xlabel='State'>

# %%
# Sample data
#data = pd.DataFrame({
   # 'Categories': ['A', 'B', 'C', 'D'],
   # 'Values': [10, 15, 7, 12]
#})

# Define colors
#colors = ['red', 'blue', 'green', 'orange']

# Create bar plot
#ax = data.plot(kind='bar', x='Categories', y='Values', color=colors)

# Add labels and title
#ax.set_xlabel('Categories')
#ax.set_ylabel('Values')
#ax.set_title('Bar Plot with Different Colors')

# Show plot
#plt.show()

# %%
#df4 = df.groupby('Gender')[['Amount']].mean(numeric_only = True).sort_values(by ='Amount',ascending = False)

# %%
#df4

# %%
#df4.plot.pie(y = 'Amount')

# %%
sns.countplot(x='Gender', data=df, palette='Set2')

# Add labels and title
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Number of Males and Females')

# Show plot
#plt.show() #3
# Out:
# Text(0.5, 1.0, 'Number of Males and Females')

# %%
df5 = df.groupby('Gender')[['Amount']].sum(numeric_only = True).sort_values(by ='Amount',ascending = False)
df5#4
# Out:
#           Amount
# Gender
# F       74307679
# M       31871146

# %%
df5.plot(kind = 'bar',xlabel='Gender',ylabel='Total Amount of all Purchases',color = colors)
#sns.barplot(data=df, x='Gender', y='Amount')
# Out:
# <Axes: xlabel='Gender', ylabel='Total Amount of all Purchases'>

# %%
sns.countplot(x='Marital_Status', data=df, palette='Set2')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x='Occupation', data=df, palette='Set2')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df10 = df.groupby('Occupation')[['Amount']].sum(numeric_only = True).sort_values(by ='Amount',ascending = False)

df10
#plt.figure(figsize=(30, 6))
#sns.barplot(data = df10, x= 'Occupation', y='Amount')
# Out:
#                    Amount
# Occupation
# IT Sector        14741862
# Healthcare       13034586
# Aviation         12599994
# Banking          10770610
# Govt              8517212
# Hospitality       6337633
# Media             6295832
# Automobile        5368596
# Chemical          5297436
# Lawyer            4981665
# Retail            4783170
# Food Processing   4070670
# Construction      3589588
# Textile           3204972
# Agriculture       2584999

# %%
#sns.barplot(data = df10, x= 'Occupation', y='Amount')
#sns.barplot(data=df10, x='Occupation', y='Amount')

# %%
plt.figure(figsize=(30, 6))
sns.countplot(x='Product_Category', data=df, palette='Set2')
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %%
df11 = df.groupby('Product_Category')[['Amount']].sum(numeric_only = True).sort_values(by ='Amount',ascending = False)
df12=df11.transpose()
df12
# Out:
# Product_Category      Food  Clothing & Apparel  Electronics & Gadgets  \
# Amount            33933883            16484472               15607657
#
# Product_Category  Footwear & Shoes  Furniture  Games & Toys  Sports Products  \
# Amount                    15575209    5440051       4331694          3635933
#
# Product_Category   Beauty     Auto  Stationery  Household items  Tupperware  \
# Amount            1959484  1935041     1676051          1569337     1155642
#
# Product_Category    Books   Decor  Pet Care  Hand & Power Tools  Veterinary  \
# Amount            1061478  730360    482277              405618      112702
#
# Product_Category  Office
# Amount             81936

# %%
#sns.barplot(data=df11, x='Product_Category', y='Amount')
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
#sales_state = df.groupby('Product_ID')[['Orders']].sum(numeric_only = True).sort_values(by ='Orders',ascending = False)

plt.figure(figsize=(30, 6))
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# ### Conclusion
